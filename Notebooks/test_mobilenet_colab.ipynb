# %% [markdown]
# # MobileNetV3 Testing on Colab
# This notebook provides a quickstart to evaluate the trained model for Age and Gender classification using testing data.

# %%
# %%bash
# # Clone or update the GitHub repo
# if [ -d /content/gender-age-prediction-mobileNetv3-modelV2/.git ]; then
#   echo 'Repository already exists, pulling latest changes'
#   cd /content/gender-age-prediction-mobileNetv3-modelV2
#   git pull
# else
#   git clone https://github.com/mohamedIzoughne/gender-age-prediction-mobileNetv3-modelV2.git /content/gender-age-prediction-mobileNetv3-modelV2
#   cd /content/gender-age-prediction-mobileNetv3-modelV2
# fi
#
# # Install requirements
# if [ -f requirements.txt ]; then
#   pip install -r requirements.txt
# else
#   # Fallback dependencies based on project usage
#   pip install torch torchvision pytorch-lightning tensorboard torchmetrics pandas pillow imagehash PyYAML
# fi
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 852.4/852.4 kB 56.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.4/983.4 kB 66.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.7/296.7 kB 30.9 MB/s eta 0:00:00
# ...
# Cloning into '/content/gender-age-prediction-mobileNetv3-modelV2'...

# %%
import sys, os

project_dir = '/content/gender-age-prediction-mobileNetv3-modelV2'

if os.path.exists(project_dir):
    os.chdir(project_dir)
    if project_dir not in sys.path:
        sys.path.insert(0, project_dir)
    print('Working directory set to', project_dir)
else:
    print('Project directory not found.')
# Out:
# Working directory set to /content/gender-age-prediction-mobileNetv3-modelV2

# %% [markdown]
# ## 2. Dataset Setup
# We will mount your Google Drive and unzip the UTKFace dataset to `/content/data/UTKFace`.
# The code automatically splits this dataset into 80% train, 10% validation, and 10% test using a fixed seed, ensuring the test set evaluates unseen data.

# %%
from google.colab import drive
drive.mount("/content/drive")

# Create the target directory
# !mkdir -p /content/data

# Unzip your UTKFace dataset (Make sure this matches the path in your Google Drive)
# !unzip -q /content/drive/MyDrive/test_cropped_faces.zip -d /content/data/UTKFace/
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## 3. Run Testing
# Select the configuration and evaluate the model. You must provide the path to your saved model checkpoint.

# %%
config_file = "config/model/my-configs/mobilenet_v3_large_aug.yaml" # @param ["config/model/my-configs/mobilenet_v3_large_aug.yaml", "config/model/my-configs/mobilenet_v3_large_no_aug.yaml", "config/model/my-configs/efficientnet_b0_aug.yaml", "config/model/my-configs/efficientnet_b0_no_aug.yaml"]
checkpoint_path = "/content/model-store/last_best_model.pth" # @param {type:"string"}
test_dataset_path = "/content/data/UTKFace" # @param {type:"string"}

# !PYTHONPATH=. python src/runners/tester.py --config {config_file} --ckpt {checkpoint_path} --ds_path {test_dataset_path}
# Out:
#  - - -
# Testing with Config:
# {'prefix': 'mobilenet_v3_large_aug', 'use_dynamic_augmentation': True, 'dynamic_augmentation_mult': 0.3, 'num_aug_bins': 9, 'model_type': 'mobilenet_v3_large', 'ds_path': '/content/data/UTKFace', 'num_epochs': 24, 'batch_size': 256, 'freeze_epochs': 0, 'gender_loss_weight': 0.8, 'base_lr': 0.0002, 'weight_decay': 0.00035, 'dropout': 0.25, 'l1_lambda': 0.0001, 'lr_scheduler': 'one_cycle', 'max_lr': 0.0048, 'anneal_strategy': 'cos', 'pct_start': 0.22, 'div_factor': 25, 'final_div_factor': 10000, 'override_cycle_epoch_count': 24, 'include_center_crop': False, 'include_color_jitter': True, 'include_gaussian_blur': True, 'include_gaussian_noise': True, 'include_random_affine': True, 'include_random_erasing': True, 'include_random_grayscale': True, 'include_random_horizontal_flip': True, 'include_random_perspective': True, 'include_random_rotation': True}
#
#  - - -
#
# Seed set to 42
# Loading model from /content/model-store/last_best_model.pth
# ...
